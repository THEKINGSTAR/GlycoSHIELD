# %% [markdown]
# ## Welcome to this tutorial, where we will learn how to coarse-grain an all-atom structure and embed it in a membrane to run a molecular dynamics simulation.

# %% [markdown]
# ## Tutorial setup
#
# Run this cell **first**. It does two things:
#
# 1. Defines the GROMACS module line used everywhere, so you load it the same way in every step. Note that since this is a python environment running bash command, the **module load** command will be used everytime we want to use GROMACS.
# 2. Builds **short** versions of the NVT / NPT / production `.mdp` files so the whole workflow runs in a few minutes on the GPU instead of hours. These short runs are for *demonstration only* — real science needs the full-length runs in `../inp_files/`.
#
# Run lengths chosen for the tutorial (Martini, dt = 20 fs):
#
# | Step |     steps |   time |
# | ---- |     ----- |   ---- |
# | NVT  |   25 000  | 0.5 ns |
# | NPT  |   50 000  |  1  ns |
# | Prod | 1 000 000 |  20 ns |

# %%
# %%bash
# # ===== Tutorial setup: create short .mdp files for a fast demo run =====
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
#
# INP=../inp_files
#
# # Short NVT: 0.5 ns
# sed 's/^nsteps.*/nsteps = 25000/'  $INP/CG_nvt.mdp  > CG_nvt_tut.mdp
# # Short NPT: 1 ns
# sed 's/^nsteps.*/nsteps = 50000/'  $INP/CG_npt.mdp  > CG_npt_tut.mdp
# # Short production: 20 ns
# sed 's/^nsteps.*/nsteps = 1000000/' $INP/CG_prod.mdp > CG_prod_tut.mdp
# sed -i 's/^nstxout-compressed.*/nstxout-compressed       = 25000 ; 0.5 ns/' CG_prod_tut.mdp
#
# echo 'Short mdp files created:'
# for f in CG_nvt_tut CG_npt_tut CG_prod_tut; do
#   printf '  %-16s ' "$f.mdp"; grep '^nsteps' $f.mdp
# done
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
# Short mdp files created:
#   CG_nvt_tut.mdp   nsteps = 25000
#   CG_npt_tut.mdp   nsteps = 50000
#   CG_prod_tut.mdp  nsteps = 1000000

# %% [markdown]
# # System preparation
#
# ## Converting all atom to coarse grain
#
# To start, we will take the all-atom structure we worked with in the previous tutorial. To convert it into a coarse-grained (CG) model, we will use a popular tool called `martinize2`. This approach is compatible with the MARTINI force field.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# martinize2 -f aa.pdb -x CG.pdb -o topol.top -dssp -p backbone -elastic
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#     INFO - general - Read 1 molecules from PDB file aa.pdb
#     INFO - step - Guessing the bonds.
#     INFO - general - 1 molecules after guessing bonds
#     INFO - step - Repairing the graph.
#     INFO - general - Applying modification N-ter to residue A-TYR241
#     INFO - general - Applying modification + to residue A-TYR241
#     INFO - general - Applying modification C-ter to residue A-TYR378
#     INFO - general - Applying modification + to residue A-TYR378
#     INFO - missing-atom - Missing atom TYR378:OXT
#     INFO - step - Dealing with modifications.
#     INFO - general - Identified the modifications ['N-ter'] on residues ['TYR241', 'TYR241', 'TYR241', 'TYR241']
#     INFO - general - Identified the modifications ['C-ter'] on residues ['TYR378', 'TYR378', 'TYR378']
#     INFO - step - Read input.
#     INFO - step - Creating the graph at the target resolution.
#     INFO - general - Applying modification mapping ('N-ter',)
#     INFO - general - Applying modification mapping ('C-ter',)
#     INFO - step - Averaging the coordinates.
#     INFO - step - Applying the links.
#     INFO - step - Placing the charge dummies.
#     INFO - step - Applying position restraints.
#     INFO - step - Setting the rubber bands.
#     INFO - step - Sorting atomids
#     INFO - step - Writing output.
#     INFO - model - Disulfide bridge found between residues A-CYS27 and A-CYS73
#     INFO - general - Please cite: McGibbon, R T; Beauchamp, K A; Harrigan, M P; Klein, C; Swails, J M; Hernández, C X; Schwantes, C R; Wang, L; Lane, T J; Pande, V S;  Biophysical Journal 2015; 10.1016/j.bpj.2015.08.015
#     INFO - general - Please cite: Kroon, P C; Grunewald, F; Barnoud, J; van Tilburg, M; Souza, P C; Wassenaar, T A; Marrink, S J;  elife 2024; 10.7554/elife.90627.2
#     INFO - general - Please cite: Souza, P C T; Alessandri, R; Barnoud, J; Thallmair, S; Faustino, I; Grünewald, F; Patmanidis, I; Abdizadeh, H; Bruininks, B M H; Wassenaar, T A; Kroon, P C; Melcr, J; Nieto, V; Corradi, V; Khan, H M; Domański, J; Javanainen, M; Martinez-Seara, H; Reuter, N; Best, R B; Vattulainen, I; Monticelli, L; Periole, X; Tieleman, D P; de Vries, A H; Marrink, S J;  Nature Methods 2021; 10.1038/s41592-021-01098-3
#     INFO - general - The only proper way to make a martini is with ice-cold gin and a bow in the direction of France. -- Winston Churchill

# %% [markdown]
# | Option         | Description                                                                                                                                                                 |
# | -------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | `-f aa.pdb`    | Specifies the input all-atom protein structure in PDB format.                                                                                                               |
# | `-x CG.pdb`    | Writes the generated coarse-grained coordinates to `CG.pdb`.                                                                                                                |
# | `-o topol.top` | Outputs the GROMACS topology file containing molecular definitions and bonded interactions.                                                                                 |
# | `-dssp`        | Automatically assigns protein secondary structure using DSSP. The assigned secondary structure determines the backbone bead types and bonded parameters in the MARTINI force field. |
# | `-p backbone`  | Generates position restraints for backbone beads, helping maintain the protein structure during equilibration.                                                              |
# | `-elastic`     | Builds an Elastic Network Model (ENM) by adding harmonic springs between nearby backbone beads to preserve the native tertiary structure during coarse-grained simulations. |
#
# ---
#
# Files generated are :
#
# - `CG.pdb`: contains the coarse-grained structure file
# - `topol.top`: topology file contains information linked to all the forcefield files
# - `molecule_0.itp`: contains forcefield information for the protein
#
# The generated forcefield file contains:
#
# - Bead definitions
# - Charges
# - Masses
# - Bond parameters
# - Angle parameters
# - Dihedral parameters
# - Elastic network springs (if `-elastic` is used)
# - Position restraints (if `-p backbone` is used)
#
# `-dssp`: The MARTINI force field assigns different backbone bead types depending on the protein's secondary structure.
#
# | Secondary Structure | Example Backbone Bead Type |
# | ------------------- | -------------------------- |
# | α-Helix             | `N0`                       |
# | β-Sheet             | `Nda`                      |
# | Coil / Loop         | `P5`                       |
#
# `-elastic`: Coarse-grained models generally have smoother energy landscapes and fewer interaction sites than atomistic models, which can make proteins more flexible than expected.
#
# The Elastic Network Model (ENM):
#
# - Preserves the native tertiary structure
# - Prevents excessive unfolding during simulations
# - Allows local fluctuations while maintaining the overall fold
#
# Elastic springs are typically created between backbone beads within a predefined distance range.
#
# ---
#
# ## Modifying topology files to suit best for our simulations
#
# We need to modify `topol.top` as the file generated is a template and missing some information about the other forcefield files. Open the `topol.top` file and add the following lines:
#
# ```
# #include "../toppar/martini_v3.0.0.itp"
# #include "../toppar/martini_v3.0.0_ffbonded_v2_openbeta.itp"
# #include "molecule_0.itp"
# #include "../toppar/martini_v3.0.0_phospholipids_PC_v2_openbeta.itp"
# #include "../toppar/martini_v3.0.0_solvents_v1.itp"
# #include "../toppar/martini_v3.0.0_ions_v1.itp"
# ```
#
# ... and delete the following lines.
#
# ```
# #include "martini.itp"
# #include "molecule_0.itp"
# ```
#
#
# ---
#
# ## Adding membrane to our system
#
# Next step is to embed the protein in the membrane. For this, we use a tool called `insane` (**IN**sert membr**ANE**) which will create a lipid bilayer of our choice (we will use POPC in this tutorial) and embed the protein. Before embedding the protein, make sure the center of the transmembrane domain of the protein is at (0,0,0) and the domain is properly aligned so that when it is inside the membrane it has the correct orientation with respect to the membrane.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# insane -f CG.pdb -p temp.top -o memb.gro -l POPC -u POPC -box 10,10,17
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
# /net/software/trainings/2026/2026-06-30-mcb-eebg/venv-mcb-eebg-14.2.0/lib/python3.13/site-packages/insane/utils.py:23: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in upper leaflet
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in lower leaflet
# ; 167 lipids in upper leaflet, 165 lipids in lower leaflet
# ; NDX Solute 1 320
# ; Charge of protein: -2.000000
# ; NDX Membrane 321 4304
# ; Charge of membrane: 0.000000
# ; Total charge: -2.000000
# ; NDX Solvent 4305 0
# ; NDX System 1 4304
# ; "I mean, the good stuff is just INSANE" --Julia Ormond

# %% [markdown]
# | Option           | Description                                                                                                                                             |
# | ---------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | `-f aligned.pdb` | Specifies the input structure (typically a coarse-grained protein) that has already been oriented correctly with respect to the membrane.               |
# | `-p temp.top`    | Outputs a temporary topology file containing the lipid composition and system information. This file is usually merged with the protein topology later. |
# | `-o memb.gro`    | Writes the complete system coordinates in GROMACS `.gro` format, including the protein and lipid bilayer.                                               |
# | `-l POPC`        | Sets the lipid type for the **lower leaflet** of the membrane to POPC.                                                                                  |
# | `-u POPC`        | Sets the lipid type for the **upper leaflet** of the membrane to POPC.                                                                                  |
# | `-box 10,10,17`  | Defines the simulation box dimensions as **10 × 10 × 17 nm** in the x, y, and z directions, respectively.                                               |
#
# ---
#
# We need to copy the information about the number of lipid molecules from the temporary topology file, `temp.top`, to the previous `topol.top` for the next steps. For example, the last two lines of `temp.top` show the lipid type in the upper and lower leaflet and the corresponding number of lipids. Copy these two lines into `topol.top`:
#
# ```
# POPC           165
# POPC           165
# ```
#
# NOTE: Make sure that the order of the molecules in the `[molecules]` section is the same as in the structure file (`.gro` or `.pdb`).
#
# ## Adding water and ions
#
# Now we have to add water and ions to the simulation box to make the system behave more like real biological or chemical environments. In MARTINI, one water bead is equivalent to four all-atom water molecules. To add water, we use the `solvate` command and a structure file of water provided as `water.gro`.

# %%
# %%bash
# # Fix topol.top after martinize2: replace placeholder includes and add lipids.
# # IMPORTANT: set POPC counts to the values printed by insane in temp.top
# # (last lines of temp.top: upper leaflet then lower leaflet).
# N_UPPER=$(tail -2 temp.top | head -1 | awk '{print $2}')
# N_LOWER=$(tail -1 temp.top | awk '{print $2}')
# echo "POPC upper=$N_UPPER  lower=$N_LOWER"
#
# cat > topol.top << EOF
# #include "../toppar/martini_v3.0.0.itp"
# #include "../toppar/martini_v3.0.0_ffbonded_v2_openbeta.itp"
# #include "molecule_0.itp"
# #include "../toppar/martini_v3.0.0_phospholipids_PC_v2_openbeta.itp"
# #include "../toppar/martini_v3.0.0_solvents_v1.itp"
# #include "../toppar/martini_v3.0.0_ions_v1.itp"
#
# [ system ]
# Title of the system in water
#
# [ molecules ]
# molecule_0    1
# POPC        ${N_UPPER}
# POPC        ${N_LOWER}
# EOF
#
# echo '--- topol.top now ---'
# cat topol.top
# Out:
# POPC upper=167  lower=165
# --- topol.top now ---
# #include "../toppar/martini_v3.0.0.itp"
# #include "../toppar/martini_v3.0.0_ffbonded_v2_openbeta.itp"
# #include "molecule_0.itp"
# #include "../toppar/martini_v3.0.0_phospholipids_PC_v2_openbeta.itp"
# #include "../toppar/martini_v3.0.0_solvents_v1.itp"
# #include "../toppar/martini_v3.0.0_ions_v1.itp"
#
# [ system ]
# Title of the system in water
#
# [ molecules ]
# molecule_0    1
# POPC        167
# POPC        165

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# gmx solvate -cp memb.gro  -cs ../inp_files/water.gro -o solvated.gro -radius 0.21 -p topol.top
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                      :-) GROMACS - gmx solvate, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx solvate -cp memb.gro -cs ../inp_files/water.gro -o solvated.gro -radius 0.21 -p topol.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. (1964)
# DOI: 10.1021/j100785a001
# -------- -------- --- Thank You --- -------- --------
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x5 boxes
# Solvent box contains 16486 atoms in 16486 residues
# Removed 3051 solvent atoms due to solvent-solvent overlap
# Removed 2789 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#       W (   1 atoms): 10646 residues
# Generated solvent containing 10646 atoms in 10646 residues
# Writing generated configuration to solvated.gro
#
# Output configuration contains 14950 atoms in 11116 residues
# Volume                 :        1700 (nm^3)
# Density                :     1972.75 (g/l)
# Number of solvent molecules:  10646
#
# Processing topology
#
# Back Off! I just backed up topol.top to ./#topol.top.1#
#
# GROMACS reminds you: "Perfect is the enemy of good." (Voltaire)
# Adding line for 10646 solvent molecules with resname (W) to topology file (topol.top)

# %% [markdown]
# | Option            | Description                                                                                                                                                  |
# | ----------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | `-cp memb.gro`    | Input coordinate file of the system to be solvated. Here, it contains the membrane + protein system.                                                        |
# | `-cs water.gro`   | Defines the solvent configuration file. In MARTINI workflows, this is often coarse-grained water (e.g., polarizable or standard MARTINI water).           |
# | `-o solvated.gro` | Output coordinate file after adding water molecules. This is the fully solvated system.                                                                     |
# | `-radius 0.21`    | Sets the minimum distance (in nm) between solvent molecules and any solute bead. Water molecules closer than this cutoff are removed to avoid overlaps.    |
# | `-p topol.top`    | Updates the topology file by adding the correct number of solvent molecules.                                                                                |
#
# ---
#
# This will generate a new coordinate file (`solvated.gro`) with added water and updated topology file, `topol.top`, with the number of water beads added.
#
# **Next we will add ions.** This is to neutralise the total charge of the system and reproduce a physiological ion environment. This is a two-step process. The first step creates a binary input file (`.tpr`) needed for ion replacement. The second step uses `genion` to replace water beads with sodium (`NA`) and chloride (`CL`) ions at a given concentration (`-conc 0.15`). This will generate a coordinate file with ions (`ionized.gro`) and an updated `topol.top` with the number of ions added.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# gmx grompp -f ../inp_files/CG_minim.mdp -c solvated.gro -p topol.top -o ionize
# echo W | gmx genion -s ionize.tpr -o ionized -p topol.top -pname NA -nname CL -neutral -conc 0.15
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                       :-) GROMACS - gmx grompp, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx grompp -f ../inp_files/CG_minim.mdp -c solvated.gro -p topol.top -o ionize
#
#
# NOTE 1 [file topol.top, line 15]:
#   System has non-zero total charge: -2.000000
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
# Number of degrees of freedom in T-Coupling group rest is 44699.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 2 [file ../inp_files/CG_minim.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# There were 2 NOTEs
#
# GROMACS reminds you: "No, no, you're not thinking, you're just being logical." (Niels Bohr)
# Setting the LD random seed to -1913033153
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'molecule_0'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:   138    Protein residues
# There are: 10978      Other residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
#                       :-) GROMACS - gmx genion, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx genion -s ionize.tpr -o ionized -p topol.top -pname NA -nname CL -neutral -conc 0.15
#
# Reading file ionize.tpr, VERSION 2025.4 (single precision)
# Reading file ionize.tpr, VERSION 2025.4 (single precision)
# Group     0 (         System) has 14950 elements
# Group     1 (        Protein) has   320 elements
# Group     2 (      Protein-H) has   320 elements
# Group     3 (        C-alpha) has     0 elements
# Group     4 (       Backbone) has     0 elements
# Group     5 (      MainChain) has     0 elements
# Group     6 (   MainChain+Cb) has     0 elements
# Group     7 (    MainChain+H) has     0 elements
# Group     8 (      SideChain) has   320 elements
# Group     9 (    SideChain-H) has   320 elements
# Group    10 (    Prot-Masses) has   320 elements
# Group    11 (    non-Protein) has 14630 elements
# Group    12 (          Other) has 14630 elements
# Group    13 (           POPC) has  3984 elements
# Group    14 (              W) has 10646 elements
# Select a group: Number of (1-atomic) solvent molecules: 10646
#
# Back Off! I just backed up topol.top to ./#topol.top.2#
# Using random seed -1677879330.
# Replacing solvent molecule 1622 (atom 5926) with NA
# Replacing solvent molecule 9648 (atom 13952) with NA
# Replacing solvent molecule 556 (atom 4860) with NA
# Replacing solvent molecule 9948 (atom 14252) with NA
# Replacing solvent molecule 8770 (atom 13074) with NA
# Replacing solvent molecule 4710 (atom 9014) with NA
# Replacing solvent molecule 9139 (atom 13443) with NA
# Replacing solvent molecule 10591 (atom 14895) with NA
# Replacing solvent molecule 8329 (atom 12633) with NA
# Replacing solvent molecule 5715 (atom 10019) with NA
# Replacing solvent molecule 230 (atom 4534) with NA
# Replacing solvent molecule 3538 (atom 7842) with NA
# Replacing solvent molecule 5105 (atom 9409) with NA
# Replacing solvent molecule 9631 (atom 13935) with NA
# Replacing solvent molecule 1638 (atom 5942) with NA
# Replacing solvent molecule 7853 (atom 12157) with NA
# Replacing solvent molecule 1802 (atom 6106) with NA
# Replacing solvent molecule 7136 (atom 11440) with NA
# Replacing solvent molecule 2570 (atom 6874) with NA
# Replacing solvent molecule 1158 (atom 5462) with NA
# Replacing solvent molecule 5542 (atom 9846) with NA
# Replacing solvent molecule 3460 (atom 7764) with NA
# Replacing solvent molecule 1469 (atom 5773) with NA
# Replacing solvent molecule 2076 (atom 6380) with NA
# Replacing solvent molecule 8448 (atom 12752) with NA
# Replacing solvent molecule 7937 (atom 12241) with NA
# Replacing solvent molecule 8366 (atom 12670) with NA
# Replacing solvent molecule 3176 (atom 7480) with NA
# Replacing solvent molecule 2273 (atom 6577) with NA
# Replacing solvent molecule 8907 (atom 13211) with NA
# Replacing solvent molecule 763 (atom 5067) with NA
# Replacing solvent molecule 8892 (atom 13196) with NA
# Replacing solvent molecule 2049 (atom 6353) with NA
# Replacing solvent molecule 3050 (atom 7354) with NA
# Replacing solvent molecule 4795 (atom 9099) with NA
# Replacing solvent molecule 1485 (atom 5789) with NA
# Replacing solvent molecule 9492 (atom 13796) with NA
# Replacing solvent molecule 6663 (atom 10967) with NA
# Replacing solvent molecule 1103 (atom 5407) with NA
# Replacing solvent molecule 2499 (atom 6803) with NA
# Replacing solvent molecule 4924 (atom 9228) with NA
# Replacing solvent molecule 89 (atom 4393) with NA
# Replacing solvent molecule 7774 (atom 12078) with NA
# Replacing solvent molecule 1379 (atom 5683) with NA
# Replacing solvent molecule 4553 (atom 8857) with NA
# Replacing solvent molecule 9731 (atom 14035) with NA
# Replacing solvent molecule 3468 (atom 7772) with NA
# Replacing solvent molecule 7200 (atom 11504) with NA
# Replacing solvent molecule 1063 (atom 5367) with NA
# Replacing solvent molecule 1004 (atom 5308) with NA
# Replacing solvent molecule 5741 (atom 10045) with NA
# Replacing solvent molecule 8777 (atom 13081) with NA
# Replacing solvent molecule 1747 (atom 6051) with NA
# Replacing solvent molecule 1588 (atom 5892) with NA
# Replacing solvent molecule 7709 (atom 12013) with NA
# Replacing solvent molecule 2251 (atom 6555) with NA
# Replacing solvent molecule 7644 (atom 11948) with NA
# Replacing solvent molecule 408 (atom 4712) with NA
# Replacing solvent molecule 1892 (atom 6196) with NA
# Replacing solvent molecule 8304 (atom 12608) with NA
# Replacing solvent molecule 4260 (atom 8564) with NA
# Replacing solvent molecule 8408 (atom 12712) with NA
# Replacing solvent molecule 5517 (atom 9821) with NA
# Replacing solvent molecule 4501 (atom 8805) with NA
# Replacing solvent molecule 7992 (atom 12296) with NA
# Replacing solvent molecule 8584 (atom 12888) with NA
# Replacing solvent molecule 10290 (atom 14594) with NA
# Replacing solvent molecule 1925 (atom 6229) with NA
# Replacing solvent molecule 8719 (atom 13023) with NA
# Replacing solvent molecule 1389 (atom 5693) with NA
# Replacing solvent molecule 9641 (atom 13945) with NA
# Replacing solvent molecule 611 (atom 4915) with NA
# Replacing solvent molecule 6262 (atom 10566) with NA
# Replacing solvent molecule 9460 (atom 13764) with NA
# Replacing solvent molecule 10087 (atom 14391) with NA
# Replacing solvent molecule 4645 (atom 8949) with NA
# Replacing solvent molecule 4373 (atom 8677) with NA
# Replacing solvent molecule 8489 (atom 12793) with NA
# Replacing solvent molecule 2720 (atom 7024) with NA
# Replacing solvent molecule 6627 (atom 10931) with NA
# Replacing solvent molecule 6703 (atom 11007) with NA
# Replacing solvent molecule 9326 (atom 13630) with NA
# Replacing solvent molecule 3777 (atom 8081) with NA
# Replacing solvent molecule 10300 (atom 14604) with NA
# Replacing solvent molecule 7902 (atom 12206) with NA
# Replacing solvent molecule 8799 (atom 13103) with NA
# Replacing solvent molecule 309 (atom 4613) with NA
# Replacing solvent molecule 10067 (atom 14371) with NA
# Replacing solvent molecule 3714 (atom 8018) with NA
# Replacing solvent molecule 6828 (atom 11132) with NA
# Replacing solvent molecule 9616 (atom 13920) with NA
# Replacing solvent molecule 1661 (atom 5965) with NA
# Replacing solvent molecule 5274 (atom 9578) with NA
# Replacing solvent molecule 2302 (atom 6606) with NA
# Replacing solvent molecule 1877 (atom 6181) with NA
# Replacing solvent molecule 6666 (atom 10970) with NA
# Replacing solvent molecule 8768 (atom 13072) with NA
# Replacing solvent molecule 3894 (atom 8198) with NA
# Replacing solvent molecule 5616 (atom 9920) with NA
# Replacing solvent molecule 10494 (atom 14798) with NA
# Replacing solvent molecule 9767 (atom 14071) with NA
# Replacing solvent molecule 8117 (atom 12421) with NA
# Replacing solvent molecule 3959 (atom 8263) with NA
# Replacing solvent molecule 10093 (atom 14397) with NA
# Replacing solvent molecule 6994 (atom 11298) with NA
# Replacing solvent molecule 8690 (atom 12994) with NA
# Replacing solvent molecule 5419 (atom 9723) with NA
# Replacing solvent molecule 123 (atom 4427) with NA
# Replacing solvent molecule 8790 (atom 13094) with NA
# Replacing solvent molecule 5699 (atom 10003) with NA
# Replacing solvent molecule 7851 (atom 12155) with NA
# Replacing solvent molecule 9418 (atom 13722) with NA
# Replacing solvent molecule 3711 (atom 8015) with NA
# Replacing solvent molecule 2539 (atom 6843) with NA
# Replacing solvent molecule 8709 (atom 13013) with NA
# Replacing solvent molecule 7840 (atom 12144) with NA
# Replacing solvent molecule 3996 (atom 8300) with NA
# Replacing solvent molecule 8775 (atom 13079) with NA
# Replacing solvent molecule 9601 (atom 13905) with NA
# Replacing solvent molecule 9619 (atom 13923) with NA
# Replacing solvent molecule 8223 (atom 12527) with NA
# Replacing solvent molecule 6339 (atom 10643) with NA
# Replacing solvent molecule 7588 (atom 11892) with NA
# Replacing solvent molecule 7533 (atom 11837) with NA
# Replacing solvent molecule 3186 (atom 7490) with NA
# Replacing solvent molecule 812 (atom 5116) with NA
# Replacing solvent molecule 6069 (atom 10373) with NA
# Replacing solvent molecule 5386 (atom 9690) with NA
# Replacing solvent molecule 387 (atom 4691) with NA
# Replacing solvent molecule 2928 (atom 7232) with NA
# Replacing solvent molecule 6727 (atom 11031) with NA
# Replacing solvent molecule 1294 (atom 5598) with NA
# Replacing solvent molecule 8156 (atom 12460) with NA
# Replacing solvent molecule 6891 (atom 11195) with NA
# Replacing solvent molecule 3577 (atom 7881) with NA
# Replacing solvent molecule 351 (atom 4655) with NA
# Replacing solvent molecule 9632 (atom 13936) with NA
# Replacing solvent molecule 4840 (atom 9144) with NA
# Replacing solvent molecule 5597 (atom 9901) with NA
# Replacing solvent molecule 8229 (atom 12533) with NA
# Replacing solvent molecule 2125 (atom 6429) with NA
# Replacing solvent molecule 2809 (atom 7113) with NA
# Replacing solvent molecule 9057 (atom 13361) with NA
# Replacing solvent molecule 5823 (atom 10127) with NA
# Replacing solvent molecule 4110 (atom 8414) with NA
# Replacing solvent molecule 2831 (atom 7135) with NA
# Replacing solvent molecule 3109 (atom 7413) with NA
# Replacing solvent molecule 7326 (atom 11630) with NA
# Replacing solvent molecule 1321 (atom 5625) with NA
# Replacing solvent molecule 2961 (atom 7265) with NA
# Replacing solvent molecule 3203 (atom 7507) with NA
# Replacing solvent molecule 3586 (atom 7890) with NA
# Replacing solvent molecule 512 (atom 4816) with NA
# Replacing solvent molecule 2797 (atom 7101) with NA
# Replacing solvent molecule 1487 (atom 5791) with NA
# Replacing solvent molecule 6687 (atom 10991) with NA
# Replacing solvent molecule 688 (atom 4992) with CL
# Replacing solvent molecule 10644 (atom 14948) with CL
# Replacing solvent molecule 7130 (atom 11434) with CL
# Replacing solvent molecule 206 (atom 4510) with CL
# Replacing solvent molecule 8040 (atom 12344) with CL
# Replacing solvent molecule 5743 (atom 10047) with CL
# Replacing solvent molecule 5267 (atom 9571) with CL
# Replacing solvent molecule 7721 (atom 12025) with CL
# Replacing solvent molecule 3451 (atom 7755) with CL
# Replacing solvent molecule 2571 (atom 6875) with CL
# Replacing solvent molecule 4334 (atom 8638) with CL
# Replacing solvent molecule 7261 (atom 11565) with CL
# Replacing solvent molecule 5477 (atom 9781) with CL
# Replacing solvent molecule 1358 (atom 5662) with CL
# Replacing solvent molecule 3252 (atom 7556) with CL
# Replacing solvent molecule 2189 (atom 6493) with CL
# Replacing solvent molecule 5147 (atom 9451) with CL
# Replacing solvent molecule 9441 (atom 13745) with CL
# Replacing solvent molecule 9611 (atom 13915) with CL
# Replacing solvent molecule 5055 (atom 9359) with CL
# Replacing solvent molecule 5215 (atom 9519) with CL
# Replacing solvent molecule 4826 (atom 9130) with CL
# Replacing solvent molecule 5989 (atom 10293) with CL
# Replacing solvent molecule 8046 (atom 12350) with CL
# Replacing solvent molecule 5181 (atom 9485) with CL
# Replacing solvent molecule 3396 (atom 7700) with CL
# Replacing solvent molecule 6812 (atom 11116) with CL
# Replacing solvent molecule 9118 (atom 13422) with CL
# Replacing solvent molecule 9049 (atom 13353) with CL
# Replacing solvent molecule 3283 (atom 7587) with CL
# Replacing solvent molecule 2435 (atom 6739) with CL
# Replacing solvent molecule 10457 (atom 14761) with CL
# Replacing solvent molecule 5617 (atom 9921) with CL
# Replacing solvent molecule 3944 (atom 8248) with CL
# Replacing solvent molecule 3540 (atom 7844) with CL
# Replacing solvent molecule 6535 (atom 10839) with CL
# Replacing solvent molecule 6146 (atom 10450) with CL
# Replacing solvent molecule 9218 (atom 13522) with CL
# Replacing solvent molecule 2812 (atom 7116) with CL
# Replacing solvent molecule 2357 (atom 6661) with CL
# Replacing solvent molecule 1980 (atom 6284) with CL
# Replacing solvent molecule 19 (atom 4323) with CL
# Replacing solvent molecule 8516 (atom 12820) with CL
# Replacing solvent molecule 8490 (atom 12794) with CL
# Replacing solvent molecule 10543 (atom 14847) with CL
# Replacing solvent molecule 209 (atom 4513) with CL
# Replacing solvent molecule 618 (atom 4922) with CL
# Replacing solvent molecule 7378 (atom 11682) with CL
# Replacing solvent molecule 5106 (atom 9410) with CL
# Replacing solvent molecule 4125 (atom 8429) with CL
# Replacing solvent molecule 293 (atom 4597) with CL
# Replacing solvent molecule 145 (atom 4449) with CL
# Replacing solvent molecule 7808 (atom 12112) with CL
# Replacing solvent molecule 1453 (atom 5757) with CL
# Replacing solvent molecule 7868 (atom 12172) with CL
# Replacing solvent molecule 4180 (atom 8484) with CL
# Replacing solvent molecule 249 (atom 4553) with CL
# Replacing solvent molecule 2514 (atom 6818) with CL
# Replacing solvent molecule 4225 (atom 8529) with CL
# Replacing solvent molecule 1435 (atom 5739) with CL
# Replacing solvent molecule 7449 (atom 11753) with CL
# Replacing solvent molecule 10328 (atom 14632) with CL
# Replacing solvent molecule 8923 (atom 13227) with CL
# Replacing solvent molecule 2707 (atom 7011) with CL
# Replacing solvent molecule 7537 (atom 11841) with CL
# Replacing solvent molecule 2911 (atom 7215) with CL
# Replacing solvent molecule 437 (atom 4741) with CL
# Replacing solvent molecule 8443 (atom 12747) with CL
# Replacing solvent molecule 6563 (atom 10867) with CL
# Replacing solvent molecule 5167 (atom 9471) with CL
# Replacing solvent molecule 9821 (atom 14125) with CL
# Replacing solvent molecule 9563 (atom 13867) with CL
# Replacing solvent molecule 2336 (atom 6640) with CL
# Replacing solvent molecule 9071 (atom 13375) with CL
# Replacing solvent molecule 10404 (atom 14708) with CL
# Replacing solvent molecule 6260 (atom 10564) with CL
# Replacing solvent molecule 824 (atom 5128) with CL
# Replacing solvent molecule 9096 (atom 13400) with CL
# Replacing solvent molecule 5756 (atom 10060) with CL
# Replacing solvent molecule 4460 (atom 8764) with CL
# Replacing solvent molecule 266 (atom 4570) with CL
# Replacing solvent molecule 3629 (atom 7933) with CL
# Replacing solvent molecule 2355 (atom 6659) with CL
# Replacing solvent molecule 9390 (atom 13694) with CL
# Replacing solvent molecule 3 (atom 4307) with CL
# Replacing solvent molecule 9140 (atom 13444) with CL
# Replacing solvent molecule 6055 (atom 10359) with CL
# Replacing solvent molecule 8082 (atom 12386) with CL
# Replacing solvent molecule 4376 (atom 8680) with CL
# Replacing solvent molecule 10453 (atom 14757) with CL
# Replacing solvent molecule 7271 (atom 11575) with CL
# Replacing solvent molecule 1522 (atom 5826) with CL
# Replacing solvent molecule 3517 (atom 7821) with CL
# Replacing solvent molecule 2469 (atom 6773) with CL
# Replacing solvent molecule 6553 (atom 10857) with CL
# Replacing solvent molecule 4412 (atom 8716) with CL
# Replacing solvent molecule 8654 (atom 12958) with CL
# Replacing solvent molecule 341 (atom 4645) with CL
# Replacing solvent molecule 3053 (atom 7357) with CL
# Replacing solvent molecule 5679 (atom 9983) with CL
# Replacing solvent molecule 5783 (atom 10087) with CL
# Replacing solvent molecule 10458 (atom 14762) with CL
# Replacing solvent molecule 2338 (atom 6642) with CL
# Replacing solvent molecule 1797 (atom 6101) with CL
# Replacing solvent molecule 5394 (atom 9698) with CL
# Replacing solvent molecule 5247 (atom 9551) with CL
# Replacing solvent molecule 2792 (atom 7096) with CL
# Replacing solvent molecule 7690 (atom 11994) with CL
# Replacing solvent molecule 2477 (atom 6781) with CL
# Replacing solvent molecule 10639 (atom 14943) with CL
# Replacing solvent molecule 10240 (atom 14544) with CL
# Replacing solvent molecule 7747 (atom 12051) with CL
# Replacing solvent molecule 3062 (atom 7366) with CL
# Replacing solvent molecule 8217 (atom 12521) with CL
# Replacing solvent molecule 9858 (atom 14162) with CL
# Replacing solvent molecule 1820 (atom 6124) with CL
# Replacing solvent molecule 3086 (atom 7390) with CL
# Replacing solvent molecule 445 (atom 4749) with CL
# Replacing solvent molecule 5391 (atom 9695) with CL
# Replacing solvent molecule 5115 (atom 9419) with CL
# Replacing solvent molecule 3488 (atom 7792) with CL
# Replacing solvent molecule 231 (atom 4535) with CL
# Replacing solvent molecule 4346 (atom 8650) with CL
# Replacing solvent molecule 8402 (atom 12706) with CL
# Replacing solvent molecule 5357 (atom 9661) with CL
# Replacing solvent molecule 4442 (atom 8746) with CL
# Replacing solvent molecule 8135 (atom 12439) with CL
# Replacing solvent molecule 7547 (atom 11851) with CL
# Replacing solvent molecule 1263 (atom 5567) with CL
# Replacing solvent molecule 8990 (atom 13294) with CL
# Replacing solvent molecule 6594 (atom 10898) with CL
# Replacing solvent molecule 8540 (atom 12844) with CL
# Replacing solvent molecule 1228 (atom 5532) with CL
# Replacing solvent molecule 8420 (atom 12724) with CL
# Replacing solvent molecule 6771 (atom 11075) with CL
# Replacing solvent molecule 6934 (atom 11238) with CL
# Replacing solvent molecule 2958 (atom 7262) with CL
# Replacing solvent molecule 4453 (atom 8757) with CL
# Replacing solvent molecule 5562 (atom 9866) with CL
# Replacing solvent molecule 2558 (atom 6862) with CL
# Replacing solvent molecule 1907 (atom 6211) with CL
# Replacing solvent molecule 2530 (atom 6834) with CL
# Replacing solvent molecule 1145 (atom 5449) with CL
# Replacing solvent molecule 7436 (atom 11740) with CL
# Replacing solvent molecule 6477 (atom 10781) with CL
# Replacing solvent molecule 9423 (atom 13727) with CL
# Replacing solvent molecule 6291 (atom 10595) with CL
# Replacing solvent molecule 4996 (atom 9300) with CL
# Replacing solvent molecule 4270 (atom 8574) with CL
# Replacing solvent molecule 2642 (atom 6946) with CL
# Replacing solvent molecule 4819 (atom 9123) with CL
# Replacing solvent molecule 7725 (atom 12029) with CL
# Replacing solvent molecule 4354 (atom 8658) with CL
# Replacing solvent molecule 463 (atom 4767) with CL
#
#
# GROMACS reminds you: "No, no, you're not thinking, you're just being logical." (Niels Bohr)
# Will try to add 156 NA ions and 154 CL ions.
# Select a continuous group of solvent molecules
# Selected 14: 'W'
#
# Processing topology
# Replacing 310 solute molecules in topology file (topol.top)  by 156 NA and 154 CL ions.

# %% [markdown]
# `echo W | gmx ...` is used to automatically pass the option `W` to the prompt, which will replace the molecule "W" with "ION". Without `echo W |`, GROMACS would prompt you interactively.

# %% [markdown]
# # Molecular Dynamics Simulation
#
# After the system is prepared, we can now proceed to the simulation. In this part, we need to provide an important file (`.mdp`), which contains parameter settings for each step. This file determines the conditions and type of simulation we want to run.

# %% [markdown]
# ## Minimisation
#
# The first step is to ensure that the energy of our system is minimized, or close to the minimum energy state. When we build the system, there is a chance that some atoms are placed too close together, which can cause steric clashes and unrealistic high energies.
#
# The minimisation step moves atoms **downhill on the potential energy surface** to find a nearby low-energy, stable configuration. This step is used to remove *bad atomic contacts* and put the system into a physically reasonable starting shape before running dynamics.
#
# The first step, `grompp`, generates a binary input file (`.tpr`) required for running energy minimisation. The second step, `mdrun`, performs the actual energy minimisation simulation.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# gmx grompp -f ../inp_files/CG_minim.mdp -c ionized.gro -p topol.top -o emsol.tpr
# gmx mdrun -deffnm emsol #-v
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                       :-) GROMACS - gmx grompp, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx grompp -f ../inp_files/CG_minim.mdp -c ionized.gro -p topol.top -o emsol.tpr
#
# Number of degrees of freedom in T-Coupling group rest is 44699.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 1 [file ../inp_files/CG_minim.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# There was 1 NOTE
#
# GROMACS reminds you: "C is quirky, flawed, and an enormous success." (Dennis Ritchie, C author)
# Setting the LD random seed to -25788498
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'molecule_0'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:   138    Protein residues
# There are: 10978      Other residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
#                       :-) GROMACS - gmx mdrun, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx mdrun -deffnm emsol
#
# Reading file emsol.tpr, VERSION 2025.4 (single precision)
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 16 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =        50000
#
# Step 59, time 0.059 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.004792, max 0.049015 (between atoms 276 and 278)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#     276    278   41.4    0.3099   0.3252      0.3100
#     278    280   30.1    0.3101   0.3045      0.3100
#
# Step 67, time 0.067 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.004463, max 0.032046 (between atoms 276 and 278)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#
# Energy minimization has stopped, but the forces have not converged to the
# requested precision Fmax < 10 (which may not be possible for your system). It
# stopped because the algorithm tried to make a new step whose size was too
# small, or there was no change in the energy since last step. Either way, we
# regard the minimization as converged to within the available machine
# precision, given your starting configuration and EM parameters.
#
# Double precision normally gives you higher accuracy, but this is often not
# needed for preparing to run molecular dynamics.
# You might need to increase your constraint accuracy, or turn
# off constraints altogether (set constraints = none in mdp file)
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to machine precision in 3229 steps,
# but did not reach the requested Fmax < 10.
# Potential Energy  = -4.4187894e+05
# Maximum force     =  2.1604076e+02 on atom 1617
# Norm of force     =  1.2472644e+01
#
# GROMACS reminds you: "Take Your Medications and Preparations and Ram It Up Your Snout" (F. Zappa)

# %% [markdown]
# | Option (grompp)  | Meaning                                               |
# | ---------------- | ----------------------------------------------------- |
# | `-f minim.mdp`   | Energy minimization parameters.                       |
# | `-c ionized.gro` | Starting structure (protein + lipids + water + ions). |
# | `-p topol.top`   | System topology.                                      |
# | `-o emsol.tpr`   | Output run input file for `mdrun`.                    |
#
# | Option (mdrun)  | Meaning                                                |
# | --------------- | ------------------------------------------------------ |
# | `-deffnm emsol` | Sets the default filename prefix for all output files. |
# | `-v`            | Verbose mode (prints progress of minimization).        |
#
# Using `-deffnm emsol`, GROMACS generates:
#
# - `emsol.gro` : final minimized structure
# - `emsol.log` : log of the minimisation process
# - `emsol.edr` : energy file (useful for analysis)
# - `emsol.trr` : trajectory of minimisation steps
# - `emsol.tpr` : copy of input run file
#
# ---
#
# ## Equilibration
#
# The next step of the simulation is equilibration. This is to bring the system into a **stable, physically realistic state** before collecting meaningful data in the production run. In this process, we bring the system to the target temperature and pressure in a step-by-step manner and prepare it for the final production run.
#
# ### Create index file
#
# Before that, we need to create an *index file*, which is used to define and group specific sets of atoms so we can easily select and work with parts of our system during analysis or simulations.
#
# In the equilibration steps, we need to define groups for separate thermostat and barostat. In our system, we created four index groups: all atoms, protein, membrane, and solvent (water + ions). Proteins, membranes, and solvent are assigned separate thermostats.
#
# Usually, a GROMACS tool `gmx make_ndx` is used to create the index file, which is interactive and must be done manually each time. However, to automate the process, we use the `MDAnalysis` tool to create the index file (`index.ndx`).

# %%
# %%bash
# # Build index.ndx natively with GROMACS (MDAnalysis not available in the workshop venv).
# # NOTE: group numbers below (1=Protein, 13=POPC, 14=W, 15=ION) come from the
# # make_ndx listing for THIS system. If you change protein/membrane, re-run
# # 'gmx make_ndx -f emsol.tpr' with only 'q' first to read the correct numbers.
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# gmx make_ndx -f emsol.tpr -o index.ndx << 'EOF'
# 14 | 15
# name 16 SOL
# name 1 PROT
# name 13 MEM
# q
# EOF
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                      :-) GROMACS - gmx make_ndx, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx make_ndx -f emsol.tpr -o index.ndx
#
#
# Reading structure file
# Reading file emsol.tpr, VERSION 2025.4 (single precision)
# Reading file emsol.tpr, VERSION 2025.4 (single precision)
#
# GROMACS reminds you: "Take Your Medications and Preparations and Ram It Up Your Snout" (F. Zappa)
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   138    Protein residues
# There are: 10978      Other residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 14950 atoms
#   1 Protein             :   320 atoms
#   2 Protein-H           :   320 atoms
#   3 C-alpha             :     0 atoms
#   4 Backbone            :     0 atoms
#   5 MainChain           :     0 atoms
#   6 MainChain+Cb        :     0 atoms
#   7 MainChain+H         :     0 atoms
#   8 SideChain           :   320 atoms
#   9 SideChain-H         :   320 atoms
#  10 Prot-Masses         :   320 atoms
#  11 non-Protein         : 14630 atoms
#  12 Other               : 14630 atoms
#  13 POPC                :  3984 atoms
#  14 W                   : 10336 atoms
#  15 ION                 :   310 atoms
#
#  nr : group      '!': not  'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom       '&': and  'del' nr         'splitres' nr   'l': list residues
#  't': atom type  '|': or   'keep' nr        'splitat' nr    'h': help
#  'r': residue              'res' nr         'chain' char
#  "name": group             'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
# Copied index group 14 'W'
# Copied index group 15 'ION'
# Merged two groups with OR: 10336 310 -> 10646
#
# >
#
# >
#
# >
#
# >

# %% [markdown]
# ## NVT Equilibration
#
# **NVT equilibration** is used in molecular dynamics to stabilize the system at a **fixed number of particles (N), volume (V), and temperature (T)** before moving to pressure equilibration (NPT) and production runs.
#
# After minimisation, the system is still not physically stable. NVT equilibration focuses on bringing the temperature to the target value in a controlled way.
#
# This is done using a thermostat, which slowly adjusts the kinetic energy of the system to reach the desired temperature.
#
# Like every simulation step, it has two stages. First, we generate a `.tpr` file for the next `mdrun` step.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# # Uses the short CG_nvt_tut.mdp from the setup cell (0.5 ns demo run).
# gmx grompp -f CG_nvt_tut.mdp -c emsol.gro -r emsol.gro -p topol.top -n index.ndx -o nvt.tpr
# gmx mdrun -deffnm nvt -nb gpu -bonded gpu
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                       :-) GROMACS - gmx grompp, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx grompp -f CG_nvt_tut.mdp -c emsol.gro -r emsol.gro -p topol.top -n index.ndx -o nvt.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file CG_nvt_tut.mdp]:
#   verlet-buffer-pressure-tolerance is ignored when verlet-buffer-tolerance
#   < 0
#
# Number of degrees of freedom in T-Coupling group SOL is 31935.00
# Number of degrees of freedom in T-Coupling group MEM is 11949.00
# Number of degrees of freedom in T-Coupling group PROT is 809.00
#
# NOTE 2 [file CG_nvt_tut.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
#
# There were 2 NOTEs
#
# GROMACS reminds you: "The Universe is Somewhere In Here" (J.G.E.M. Fraaije)
# Setting the LD random seed to -204606549
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'molecule_0'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Taking velocities from 'emsol.gro', all velocities are zero
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# This run will generate roughly 1 Mb of data
#                       :-) GROMACS - gmx mdrun, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx mdrun -deffnm nvt -nb gpu -bonded gpu
#
# Reading file nvt.tpr, VERSION 2025.4 (single precision)
# Can not increase nstlist because verlet-buffer-tolerance is not set or used
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged and most bonded interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 16 OpenMP threads
#
# starting mdrun 'Title of the system in water'
# 25000 steps,    250.0 ps.
#
# Writing final coordinates.
#
#                Core t (s)   Wall t (s)        (%)
#        Time:       78.158        4.885     1599.9
#                  (ns/day)    (hour/ns)
# Performance:     4421.727        0.005
#
# GROMACS reminds you: "If a rat is a good model for your emotional life, you're in big trouble." (Robert Sapolsky)

# %% [markdown]
# Note that in the `grompp` step, we used an extra parameter apart from `-n index.ndx` — `-r emsol.gro`. This is important for **position restraints** for the reference structure. It helps the structure not move too much during the equilibration steps compared to the solvent.
#
# ---
#
# ## NPT Equilibration
#
# **NPT equilibration** is used in molecular dynamics to bring the system to the correct **pressure and density**, after temperature has already been stabilized in NVT.
#
# In NPT, the system is kept at constant number of particles (N), pressure (P), and temperature (T).
#
# This step adjusts the system density, distributes water molecules more evenly, and allows the box size to change to remove vacuum gaps or overly compressed regions.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# # Uses the short CG_npt_tut.mdp from the setup cell (1 ns demo run).
# # -t nvt.cpt carries velocities over from NVT for a smooth continuation.
# gmx grompp -f CG_npt_tut.mdp -c nvt.gro -r nvt.gro -p topol.top -t nvt.cpt -n index.ndx -o npt.tpr -maxwarn 1
# gmx mdrun -deffnm npt -nb gpu -bonded gpu
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                       :-) GROMACS - gmx grompp, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx grompp -f CG_npt_tut.mdp -c nvt.gro -r nvt.gro -p topol.top -t nvt.cpt -n index.ndx -o npt.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file CG_npt_tut.mdp]:
#   verlet-buffer-pressure-tolerance is ignored when verlet-buffer-tolerance
#   < 0
#
#
# WARNING 1 [file CG_npt_tut.mdp]:
#   For proper integration of the C-rescale barostat, tau-p (4) should be at
#   least 25 times larger than nstpcouple*dt (0.4)
#
# Number of degrees of freedom in T-Coupling group SOL is 31935.00
# Number of degrees of freedom in T-Coupling group MEM is 11949.00
# Number of degrees of freedom in T-Coupling group PROT is 809.00
#
# NOTE 2 [file CG_npt_tut.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Last frame         -1 time  250.000
#
# There were 2 NOTEs
#
# There was 1 WARNING
#
# GROMACS reminds you: "Nothing in biology makes sense except in the light of evolution." (Theodosius Dobzhansky)
# Setting the LD random seed to -1119887654
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'molecule_0'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Taking velocities from 'nvt.gro'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
#
# Using frame at t = 250 ps
#
# Starting time for run is 0 ps
#
# This run will generate roughly 1 Mb of data
#                       :-) GROMACS - gmx mdrun, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx mdrun -deffnm npt -nb gpu -bonded gpu
#
# Reading file npt.tpr, VERSION 2025.4 (single precision)
# Can not increase nstlist because verlet-buffer-tolerance is not set or used
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged and most bonded interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 16 OpenMP threads
#
# starting mdrun 'Title of the system in water'
# 50000 steps,   1000.0 ps.
#
# Writing final coordinates.
#
#                Core t (s)   Wall t (s)        (%)
#        Time:      167.593       10.475     1599.9
#                  (ns/day)    (hour/ns)
# Performance:     8248.439        0.003
#
# GROMACS reminds you: "Remember, being healthy is basically dying as slowly as possible." (Ricky Gervais)

# %% [markdown]
# Here, we added another parameter, `-t nvt.cpt`, which tells the program to use the velocities of the particles from the last simulation. This allows the simulation to continue smoothly from NVT and prevents the generation of random velocities for the particles.
#
# ---
#
# ## Production run
#
# This is the final stage of the simulation workflow. After energy minimization and equilibration (NVT + NPT), the system is now ready for meaningful data collection. The system is now allowed to explore real dynamics, and no position restraints are used on the atoms.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# # Uses the short CG_prod_tut.mdp from the setup cell (5 ns demo run).
# gmx grompp -f CG_prod_tut.mdp -c npt.gro -p topol.top -n index.ndx -o prod.tpr -maxwarn 1
# gmx mdrun -deffnm prod -nb gpu -bonded gpu
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                       :-) GROMACS - gmx grompp, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx grompp -f CG_prod_tut.mdp -c npt.gro -p topol.top -n index.ndx -o prod.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file CG_prod_tut.mdp]:
#   verlet-buffer-pressure-tolerance is ignored when verlet-buffer-tolerance
#   < 0
#
#
# WARNING 1 [file CG_prod_tut.mdp]:
#   For proper integration of the C-rescale barostat, tau-p (4) should be at
#   least 25 times larger than nstpcouple*dt (0.4)
#
# Number of degrees of freedom in T-Coupling group SOL is 31935.00
# Number of degrees of freedom in T-Coupling group MEM is 11949.00
# Number of degrees of freedom in T-Coupling group PROT is 809.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "There's a limit to how many times you can read how great you are and what an inspiration you are, but I'm not there yet." (Randy Pausch)
# Setting the LD random seed to -1317021005
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'molecule_0'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Taking velocities from 'npt.gro'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# This run will generate roughly 4 Mb of data
#                       :-) GROMACS - gmx mdrun, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx mdrun -deffnm prod -nb gpu -bonded gpu
#
# Reading file prod.tpr, VERSION 2025.4 (single precision)
# Can not increase nstlist because verlet-buffer-tolerance is not set or used
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged and most bonded interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 16 OpenMP threads
#
# starting mdrun 'Title of the system in water'
# 1000000 steps,  20000.0 ps.
#
# Writing final coordinates.
#
#                Core t (s)   Wall t (s)        (%)
#        Time:     3180.326      198.771     1600.0
#                  (ns/day)    (hour/ns)
# Performance:     8693.442        0.003
#
# GROMACS reminds you: "The three principal virtues of a programmer are Laziness, Impatience, and Hubris" (Larry Wall)

# %% [markdown]
# # Post Processing
#
# Before post processing, we have to create another index file. This helps in analysing different domains of the proteins, membranes, etc.
#
# To make it easier to work with and to speed up the analysis, it is better to remove solvent (when we are not dealing with analysis related to water/ions). Solvent takes up a lot of space and can reduce the speed of post-processing.
#
# For better organisation of files, we also create another folder, e.g., `analysis`.

# %%
# Optional: a folder to keep analysis outputs tidy.
# NOTE: we stay in the exercise/ directory for all commands below,
# because 'cd' in a Python cell does NOT carry over to %%bash cells.
import os
os.makedirs('analysis', exist_ok=True)
print('analysis/ ready; staying in', os.getcwd())
# Out:
# analysis/ ready; staying in /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise

# %% [markdown]
# ## Creating index file
#
# In this `index_analysis.ndx` file, we have different groups of atoms such as protein, membranes, transmembrane domain of the protein, etc. This helps to analyse the behaviour of different groups with each other.

# %%
# %%bash
# # Build index_analysis.ndx natively (MDAnalysis/pkg_resources unavailable in the venv).
# # Group numbers from 'gmx make_ndx -f prod.tpr': 1=Protein, 13=POPC, 14=W, 15=ION.
# # Transmembrane = atoms 242-312 (equals MDAnalysis 'bynum 242:312').
# # not_SOL = everything except water and ions (protein + membrane).
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# gmx make_ndx -f prod.tpr -o index_analysis.ndx << 'EOF'
# name 1 PROT
# a 242-312
# name 16 Transmembrane
# name 13 MEM
# ! 14 & ! 15
# name 17 not_SOL
# q
# EOF
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                      :-) GROMACS - gmx make_ndx, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx make_ndx -f prod.tpr -o index_analysis.ndx
#
#
# Reading structure file
# Reading file prod.tpr, VERSION 2025.4 (single precision)
# Reading file prod.tpr, VERSION 2025.4 (single precision)
#
# GROMACS reminds you: "Just Because the Sun Wants a Place In the Sky" (F. Zappa)
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:   138    Protein residues
# There are: 10978      Other residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 14950 atoms
#   1 Protein             :   320 atoms
#   2 Protein-H           :   320 atoms
#   3 C-alpha             :     0 atoms
#   4 Backbone            :     0 atoms
#   5 MainChain           :     0 atoms
#   6 MainChain+Cb        :     0 atoms
#   7 MainChain+H         :     0 atoms
#   8 SideChain           :   320 atoms
#   9 SideChain-H         :   320 atoms
#  10 Prot-Masses         :   320 atoms
#  11 non-Protein         : 14630 atoms
#  12 Other               : 14630 atoms
#  13 POPC                :  3984 atoms
#  14 W                   : 10336 atoms
#  15 ION                 :   310 atoms
#
#  nr : group      '!': not  'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom       '&': and  'del' nr         'splitres' nr   'l': list residues
#  't': atom type  '|': or   'keep' nr        'splitat' nr    'h': help
#  'r': residue              'res' nr         'chain' char
#  "name": group             'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
#
# >
# Found 71 atoms in range 242-312
#
# >
#
# >
#
# >
# Copied index group 14 'W'
# Complemented group: 4614 atoms
# Copied index group 15 'ION'
# Complemented group: 14640 atoms
# Merged two groups with AND: 4614 14640 -> 4304
#
# >
#
# >

# %% [markdown]
# ## Correction of PBC
#
# During MD simulation, periodic boundary conditions are used such that molecules leaving one side of the box re-enter from the opposite side. This creates an effectively infinite system, which is desirable.
#
# However, for certain analysis or visualisation, this can result in “broken” molecules or fragmented trajectories.
#
# To fix this, we apply a correction to make the molecules whole again. We use a GROMACS tool called `trjconv` for this.

# %%
# %%bash
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# # Centre on the transmembrane domain, make molecules whole, strip solvent.
# # Redirect feeds two selections: 'Transmembrane' (centering), 'not_SOL' (output).
# gmx trjconv -f prod.xtc -s prod.tpr -o prod_noW.xtc -n index_analysis.ndx -center -pbc mol -ur compact <<< "Transmembrane not_SOL"
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                      :-) GROMACS - gmx trjconv, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx trjconv -f prod.xtc -s prod.tpr -o prod_noW.xtc -n index_analysis.ndx -center -pbc mol -ur compact
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file prod.tpr, VERSION 2025.4 (single precision)
# Reading file prod.tpr, VERSION 2025.4 (single precision)
# Group     0 (         System) has 14950 elements
# Group     1 (           PROT) has   320 elements
# Group     2 (      Protein-H) has   320 elements
# Group     3 (        C-alpha) has     0 elements
# Group     4 (       Backbone) has     0 elements
# Group     5 (      MainChain) has     0 elements
# Group     6 (   MainChain+Cb) has     0 elements
# Group     7 (    MainChain+H) has     0 elements
# Group     8 (      SideChain) has   320 elements
# Group     9 (    SideChain-H) has   320 elements
# Group    10 (    Prot-Masses) has   320 elements
# Group    11 (    non-Protein) has 14630 elements
# Group    12 (          Other) has 14630 elements
# Group    13 (            MEM) has  3984 elements
# Group    14 (              W) has 10336 elements
# Group    15 (            ION) has   310 elements
# Group    16 (  Transmembrane) has    71 elements
# Group    17 (        not_SOL) has  4304 elements
# Select a group: Group     0 (         System) has 14950 elements
# Group     1 (           PROT) has   320 elements
# Group     2 (      Protein-H) has   320 elements
# Group     3 (        C-alpha) has     0 elements
# Group     4 (       Backbone) has     0 elements
# Group     5 (      MainChain) has     0 elements
# Group     6 (   MainChain+Cb) has     0 elements
# Group     7 (    MainChain+H) has     0 elements
# Group     8 (      SideChain) has   320 elements
# Group     9 (    SideChain-H) has   320 elements
# Group    10 (    Prot-Masses) has   320 elements
# Group    11 (    non-Protein) has 14630 elements
# Group    12 (          Other) has 14630 elements
# Group    13 (            MEM) has  3984 elements
# Group    14 (              W) has 10336 elements
# Group    15 (            ION) has   310 elements
# Group    16 (  Transmembrane) has    71 elements
# Group    17 (        not_SOL) has  4304 elements
# Reading frame       0 time    0.000
# Precision of prod.xtc is 0.01 (nm)
# Using output precision of 0.001 (nm)
# Last frame         40 time 20000.000    ->  frame     39 time 19500.000
#  ->  frame     40 time 20000.000
# Last written: frame     40 time 20000.000
#
#
# GROMACS reminds you: "Just Because the Sun Wants a Place In the Sky" (F. Zappa)
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for centering
# Selected 16: 'Transmembrane'
# Select group for output
# Selected 17: 'not_SOL'

# %% [markdown]
# | File                    | Meaning                                                |
# | ----------------------- | ------------------------------------------------------ |
# | `-f ../prod.xtc`        | Raw production trajectory                              |
# | `-s ../prod.tpr`        | Run input file (provides structure/topology reference) |
# | `-o prod_noW.xtc`       | Output cleaned trajectory                              |
# | `-n index_analysis.ndx` | Index file defining custom groups                      |
# | `-center`              | Centers on a chosen group (here **Transmembrane**)     |
# | `-pbc mol`             | Keeps whole molecules intact                           |
# | `-ur compact`          | Minimizes box volume representation                    |
#
# `<<< "Transmembrane not_SOL"`: This is bash input redirection, not a GROMACS option. It automatically provides answers to the interactive prompts from `trjconv` when it asks for group selections — here, **"Transmembrane"** for centering and **"not_SOL"** (all atoms except solvent) for output.

# %%
# %%bash
# # Make a solvent-free single-frame structure for visualization.
# module load GCC/14.2.0 GROMACS/2025.4-CUDA-12.8.0-SMP
# # take the first frame of the cleaned trajectory as a .gro (or .pdb) snapshot
# echo "not_SOL" | gmx trjconv -f prod_noW.xtc -s prod.tpr -n index_analysis.ndx -o prod_vis.pdb -dump 0
# ls -la prod_vis.pdb
# Out:
#  GCCcore/14.2.0 unloaded.
#  GCC/14.2.0 unloaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  CUDA/12.8.0 unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.5 unloaded.
#  ncurses/6.3 loaded.
#  libreadline/8.2 loaded.
#  Tcl/8.6.16 unloaded.
#  SQLite/3.47.2 unloaded.
#  XZ/5.6.3 unloaded.
#  libffi/3.4.5 unloaded.
#  OpenSSL/3 unloaded.
#  Python/3.13.1 unloaded.
#  GCCcore/14.2.0 loaded.
#  GCC/14.2.0 loaded.
#  zlib/1.3.1 unloaded.
#  zlib/1.3.1 loaded.
#  binutils/2.42 unloaded.
#  binutils/2.42 loaded.
#  bzip2/1.0.8 unloaded.
#  bzip2/1.0.8 loaded.
#  libreadline/8.2 unloaded.
#  ncurses/6.3 unloaded.
#  ncurses/6.5 loaded.
#  libreadline/8.2 loaded.
#  CUDA/12.8.0 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#  Tcl/8.6.16 loaded.
#  SQLite/3.47.2 loaded.
#  XZ/5.6.3 loaded.
#  libffi/3.4.5 loaded.
#  OpenSSL/3 loaded.
#  Python/3.13.1 loaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP unloaded.
#  GROMACS/2025.4-CUDA-12.8.0-SMP loaded.
#                      :-) GROMACS - gmx trjconv, 2025.4 (-:
#
# Executable:   /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP/bin/gmx
# Data prefix:  /net/software/v1/software/GROMACS/2025.4-GCC-14.2.0-CUDA-12.8.0-SMP
# Working dir:  /net/tscratch/people/tutorial140/workspaces/2026-06-30-mcb-eebg/notebooks/EEBG_workshop/CG_Membrane/exercise
# Command line:
#   gmx trjconv -f prod_noW.xtc -s prod.tpr -n index_analysis.ndx -o prod_vis.pdb -dump 0
#
# Will write pdb: Protein data bank file
# Reading file prod.tpr, VERSION 2025.4 (single precision)
# Reading file prod.tpr, VERSION 2025.4 (single precision)
# Group     0 (         System) has 14950 elements
# Group     1 (           PROT) has   320 elements
# Group     2 (      Protein-H) has   320 elements
# Group     3 (        C-alpha) has     0 elements
# Group     4 (       Backbone) has     0 elements
# Group     5 (      MainChain) has     0 elements
# Group     6 (   MainChain+Cb) has     0 elements
# Group     7 (    MainChain+H) has     0 elements
# Group     8 (      SideChain) has   320 elements
# Group     9 (    SideChain-H) has   320 elements
# Group    10 (    Prot-Masses) has   320 elements
# Group    11 (    non-Protein) has 14630 elements
# Group    12 (          Other) has 14630 elements
# Group    13 (            MEM) has  3984 elements
# Group    14 (              W) has 10336 elements
# Group    15 (            ION) has   310 elements
# Group    16 (  Transmembrane) has    71 elements
# Group    17 (        not_SOL) has  4304 elements
# Reading frame       0 time    0.000
# Precision of prod_noW.xtc is 0.01 (nm)
# Reading frame       1 time  500.000
# Dumping frame at t= 0 ps
#  ->  frame      0 time    0.000
# Last written: frame      0 time    0.000
#
#
# GROMACS reminds you: "I have had my results for a long time, but I do not yet know how I am to arrive at them." (Carl Friedrich Gauss)
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 17: 'not_SOL'
# -rw-r--r-- 1 tutorial140 tutorial 340239 Jun 30 13:47 prod_vis.pdb

# %%
# Visualization with nglview.
# Two issues are worked around here, both caused by the shared read-only venv,
# not by the simulation:
#   1) pkg_resources is missing (setuptools absent in this Python 3.13 venv),
#      so nglview fails to import. We inject a tiny stub before importing it.
#   2) the inline JupyterLab widget version is mismatched (backend wants
#      nglview-js-widgets 3.1.4, the Hub has 3.1.5), so the inline viewer
#      will not render. We export a standalone HTML file instead and open it
#      in the browser (right-click view.html in the file browser -> Download).
import sys, types

# --- stub pkg_resources so nglview can import ---
if 'pkg_resources' not in sys.modules:
    stub = types.ModuleType('pkg_resources')
    class _Dist:
        version = '0'
    stub.get_distribution = lambda *a, **k: _Dist()
    stub.DistributionNotFound = Exception
    stub.resource_filename = lambda *a, **k: ''
    sys.modules['pkg_resources'] = stub

import nglview as nv

# Visualize the actual pipeline output (solvent stripped), not the nonexistent aa2.pdb.
# Martini is coarse-grained, so 'cartoon' does not apply; we render beads instead.
view = nv.show_file('prod_vis.pdb')
view.clear_representations()
view.add_representation('point', selection='all')
view.add_representation('spacefill', selection='not (resname POPC)', radius=0.6)

# Export to a standalone HTML file (bypasses the JupyterLab widget version mismatch).
nv.write_html('view.html', [view])
print('Wrote view.html - right-click it in the file browser and Download, then open locally.')
# Out:
# Wrote view.html - right-click it in the file browser and Download, then open locally.
